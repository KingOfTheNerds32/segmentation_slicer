# %%
import numpy as np
import pandas as pd
pd.options.mode.chained_assignment = None

# %%
csv_sep = '|'

# %%
metrics = pd.read_csv('metrics.csv', sep = csv_sep)
metrics.head()
# Out:
#                    bucket    var                                         label
# 0  Segment Classification  SEG01       Typing Tool Classification: Family Time
# 1  Segment Classification  SEG02  Typing Tool Classification: Romantic Getaway
# 2  Segment Classification  SEG03        Typing Tool Classification: Well-being
# 3  Segment Classification  SEG04       Typing Tool Classification: Rest and Go
# 4  Segment Classification  SEG05   Typing Tool Classification: Social Identity

# %%
df = pd.read_csv('FlatTest_Full.csv', sep = csv_sep)
df.head()
# Out:
#    Weight_Completes  Respondent_ID  Country  S3_DV  TravelAssignment  T4a  T5  \
# 0          0.498927              1        4      1                 3    5   2
# 1          0.545428              2        4      4                 3    4   2
# 2          0.822232              3        3      3                 3    3   8
# 3          1.853067              4        3      4                 1    5   1
# 4          0.982030              5        3      4                 3    3   1
#
#    O26D  O26D2_2nd  O26D2_3rd  ...   BTCF  BPSF  WBDIM  RGDIM  FTDIM  SBDIM  \
# 0    60         61         75  ...    NaN   NaN    NaN    NaN    NaN    NaN
# 1   146          0          0  ...    NaN   NaN    NaN    NaN    NaN    NaN
# 2   185          0          0  ...    NaN   NaN    NaN    NaN    NaN    NaN
# 3   112         54          1  ...    NaN   NaN    NaN    NaN    NaN    NaN
# 4    62        113         54  ...    NaN   NaN    NaN    NaN    NaN    NaN
#
#    MBPDIM  BPDIM  BBIDIM  SDIM
# ...

# %%
filt_ban = pd.read_csv('Filters.csv', sep = csv_sep)
filt_ban.head()
# Out:
#      group      var  filter_val           label filter banner
# 0  Country  Country         NaN   All Countries   True   True
# 1  Country  Country           1   United States   True   True
# 2  Country  Country           2  United Kingdom   True   True
# 3  Country  Country           3           China   True   True
# 4  Country  Country           4         Germany   True   True

# %%
filt_ban_vars = ['Weight_Completes', 'Respondent_ID']
filt_ban_vars += filt_ban['var'].unique().tolist()

# %%
filt_ban_vars
# Out:
# ['Country',
#  'S3_DV',
#  'SEG01',
#  'SEG02',
#  'SEG03',
#  'SEG04',
#  'SEG05',
#  'SEG06',
#  'Weight_Completes',
#  'Respondent_ID']

# %%
respondents = df[filt_ban_vars]

# %%
respondents
# Out:
#       Weight_Completes  Respondent_ID  Country  S3_DV  SEG01  SEG02  SEG03  \
# 0             0.498927              1        4      1      0      1      0
# 1             0.545428              2        4      4      1      0      0
# 2             0.822232              3        3      3      0      0      0
# 3             1.853067              4        3      4      1      0      0
# 4             0.982030              5        3      4      1      0      0
# 5             0.736577              6        3      2      1      0      0
# 6             0.390348              7        3      2      1      0      0
# 7             0.301840              8        5      2      0      0      0
# 8             0.770703              9        5      2      0      0      0
# 9             0.253127             10        4      2      0      0      0
# 10            0.718764             11        1      3      0      0      1
# ...

# %%
respondents['Project_ID'] = 123456
# Out:
#       Weight_Completes  Respondent_ID  Country  S3_DV  SEG01  SEG02  SEG03  \
# 0             0.498927              1        4      1      0      1      0
# 1             0.545428              2        4      4      1      0      0
# 2             0.822232              3        3      3      0      0      0
# 3             1.853067              4        3      4      1      0      0
# 4             0.982030              5        3      4      1      0      0
# 5             0.736577              6        3      2      1      0      0
# 6             0.390348              7        3      2      1      0      0
# 7             0.301840              8        5      2      0      0      0
# 8             0.770703              9        5      2      0      0      0
# 9             0.253127             10        4      2      0      0      0
# 10            0.718764             11        1      3      0      0      1
# ...

# %%
respondents.to_json('respondents.json', orient = "records")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-fa6ccb6385ab> in <module>()
# ----> 1 respondents.to_json('respondents.json', orient = "records", lines = True)
#
# TypeError: to_json() got an unexpected keyword argument 'lines'
